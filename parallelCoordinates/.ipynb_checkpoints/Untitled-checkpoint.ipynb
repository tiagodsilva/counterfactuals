# %%
import pandas as pd 
import os

# %%
dataPath = "projection/data/recFiltering/" 
steps = [] 
for i in range(3): 
    csvDir = dataPath + "Step" + str(i) + "/" 
    csvs = {} 
    for file in os.listdir(csvDir): 
        name = file[:len(file) - 4] 
        csvs[name] = pd.read_csv(csvDir + file).rename(columns = {"Unnamed: 0": "x"})  
    steps.append(csvs)

# %%
for i in range(len(steps)):
    df = pd.DataFrame() 
    for k, v in steps[i].items():
# Out:
#           x    1
# 0  0.000000  0.0
# 1  0.166667  0.0
# 2  0.333333  0.0
# 3  0.500000  0.0
# 4  0.666667  0.0
# 5  0.833333  0.0
# 6  1.000000  0.0
# 7  1.166667  0.0
#    x      1
# 0  3  0.002
# 1  2  0.008
# 2  1  0.024
# 3  0  0.052
#            x      1
# 0   3.266760  0.014
# 1   2.990565  0.016
# 2   2.714370  0.018
# 3   2.438176  0.020
# 4   2.161981  0.032
# 5   1.885786  0.040
# 6   1.609591  0.048
# 7   1.333396  0.064
# 8   1.057202  0.090
# 9   0.781007  0.116
# 10  0.504812  0.162
#           x      1
# 0  1.166667  0.000
# 1  1.000000  0.000
# 2  0.833333  0.012
# 3  0.666667  0.026
# 4  0.500000  0.048
# 5  0.333333  0.070
# 6  0.166667  0.096
# 7  0.000000  0.138
#    x      1
# 0  0  0.000
# 1  1  0.312
#            x      1
# 0   0.012348  0.002
# 1   0.011113  0.002
# 2   0.009878  0.002
# 3   0.008644  0.002
# 4   0.007409  0.002
# 5   0.006174  0.002
# 6   0.004939  0.002
# 7   0.003704  0.002
# 8   0.002470  0.002
# 9   0.001235  0.002
# 10  0.000000  0.002
# ...
